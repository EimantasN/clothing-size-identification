# %% [markdown]
# # Generating validation image mask from json polygons

# %%
from utils.data_generation import *

# %%
val_img_dir = "./data/val/imgs/"
val_mask_dir = "./data/val/mask/"
val_data = "./data/val/val_mask.json"

val_imgs = print_img_in_folder(val_img_dir, True)
# Out:
# ['IMG_9429.jpg', 'IMG_9386.jpg', 'IMG_9422.jpg', 'IMG_9329.jpg', 'IMG_9389.jpg', 'IMG_9315.jpg', 'IMG_9388.jpg', 'IMG_9398.jpg', 'DSC_2704.jpg', 'IMG_9330.jpg', 'DSC_2714.jpg', 'DSC_2702.jpg', 'DSC_2707.jpg', 'IMG_9279.jpg', 'DSC_2721.jpg', 'IMG_9263.jpg', 'DSC_2708.jpg', 'IMG_9283.jpg', 'IMG_9326.jpg', 'DSC_2716.jpg', 'DSC_2722.jpg', 'IMG_9430.jpg', 'IMG_9427.jpg']

# %%
generate_mask_images(val_data, val_img_dir, val_mask_dir)
# Out:
# /data/clothing-size-identification/utils/data_generation.py:58: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(28,20))
